# %% [markdown]
# # Extracting condition-specific trials
#
# The aim of this section is to extract the trials according to the trigger channel. We will explain how the events can be generated from the stimulus channels and how to extract condition specific trials (epochs). Once the trials are extracted, bad epochs will be identified and excluded on based on their peak-to-peak signal amplitude.
#
# ## Preparation
#
# Import the relevant Python modules:

# %%
# mount the drive (you'll have to click through the popup to allow it)

from IPython.display import clear_output

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# !pip install openneuro-py
# !pip install --upgrade mne-bids[full]
# !pip install ipympl  # for the widgets in ipynb

clear_output()  # just clear everything because the output is gross and unnecessary

# %%
import os.path as op
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import mne
from mne_bids import BIDSPath, read_raw_bids

# %% [markdown]
# ### File overview
# The chapter relies on the input file (embedded in the BIDS structure):
# ~~~
# <BIDS_ROOT>/derivatives/Preprocessing/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-01_ica.fif
# <BIDS_ROOT>/derivatives/Preprocessing/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-02_ica.fif
#
# <BIDS_ROOT>/derivatives/Preprocessing/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-01_ann.fif
# <BIDS_ROOT>/derivatives/Preprocessing/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-02_ann.fif
# ~~~
# and generates the output files
# ~~~
# <BIDS_ROOT>/derivatives/Analysis/sub-01/ses-01/meg/sub-01_ses-01_task-SpAtt_run-12_epo.fif
# ~~~

# %% [markdown]
# Set the paths for the data and results. Note that these will depend on your local setup.

# %%
subject = 'CB069'
session = '1'
task = 'dur'
run = '01'
meg_suffix = 'meg'
ica_suffix = 'ica'
epo_suffix = 'epo'

preproc_root = 'drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing'
deriv_root = 'drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/analysis'

bids_path_preproc = BIDSPath(subject=subject, session=session,
            task=task, run=run, suffix=ica_suffix, datatype='meg',
            root=preproc_root, extension='.fif', check=False)

bids_path = BIDSPath(subject=subject, session=session,
            task=task, run=run, suffix=epo_suffix, datatype='meg',
            root=deriv_root, extension='.fif', check=False).mkdir()

deriv_file = bids_path.basename.replace('run-01', 'run-00')  # run 12 -> run 01 concatenated with run 02
deriv_fname = op.join(bids_path.directory, deriv_file)

print(bids_path_preproc.fpath)
print(deriv_fname)
# Out:
# drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-01_ica.fif
# drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/analysis/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-00_epo.fif

# %% [markdown]
# ## Reading the events from the stimulus channels
# First read all the events from the stimulus channel (in our case, STI01). We will loop over the 2 fif-files created in the previous step.

# %%
# This section only runs on run=01 for illustration purposes
raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False}, verbose=True)
# Out:
# Opening raw data file drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-01_ica.fif...
# <ipython-input-4-2b4851b22b74>:2: RuntimeWarning: This filename (drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-01_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False}, verbose=True)
#     Range : 9000 ... 511999 =      9.000 ...   511.999 secs
# Ready.
# <ipython-input-4-2b4851b22b74>:2: RuntimeWarning: Did not find any events.tsv associated with sub-CB069_ses-1_task-dur_run-01.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*events.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False}, verbose=True)
# <ipython-input-4-2b4851b22b74>:2: RuntimeWarning: Did not find any channels.tsv associated with sub-CB069_ses-1_task-dur_run-01.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*channels.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False}, verbose=True)
# <ipython-input-4-2b4851b22b74>:2: RuntimeWarning: Did not find any meg.json associated with sub-CB069_ses-1_task-dur_run-01.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*meg.json"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False}, verbose=True)
# <ipython-input-4-2b4851b22b74>:2: RuntimeWarning: participants.tsv file not found for drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-01_ica.fif
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':False}, verbose=True)

# %%
# Reading the events from the raw file
events, events_id = mne.events_from_annotations(raw, event_id='auto')
# Out:
# Used Annotations descriptions: ['1000ms', '1500ms', '500ms', 'blank offset', 'blink', 'center', 'face01', 'face02', 'face03', 'face04', 'face05', 'face06', 'face07', 'face08', 'face09', 'face10', 'face11', 'face13', 'face14', 'face15', 'face16', 'face17', 'face18', 'face19', 'face20', 'false02', 'false03', 'false04', 'false05', 'false06', 'false07', 'false09', 'false10', 'false11', 'false12', 'false13', 'false14', 'false16', 'false17', 'false18', 'false19', 'false20', 'left', 'letter01', 'letter02', 'letter03', 'letter04', 'letter05', 'letter07', 'letter08', 'letter09', 'letter10', 'letter11', 'letter12', 'letter13', 'letter14', 'letter15', 'letter16', 'letter17', 'letter19', 'letter20', 'object01', 'object02', 'object03', 'object05', 'object06', 'object07', 'object08', 'object09', 'object10', 'object11', 'object12', 'object13', 'object14', 'object15', 'object17', 'object18', 'object19', 'response', 'right', 'sequence01', 'sequence02', 'sequence03', 'sequence04', 'sequence05', 'start experiment', 'stimulus offset', 'task irrelevant', 'task relevant non target', 'task relevant target', 'trial01', 'trial02', 'trial03', 'trial04', 'trial05', 'trial06', 'trial07', 'trial08', 'trial09', 'trial10', 'trial11', 'trial12', 'trial13', 'trial14', 'trial15', 'trial16', 'trial17', 'trial18', 'trial19', 'trial20', 'trial21', 'trial22', 'trial23', 'trial24', 'trial25', 'trial26', 'trial27', 'trial28', 'trial29', 'trial30', 'trial31', 'trial32', 'trial33', 'trial34', 'trial35', 'trial36', 'trial37', 'trial38']

# %% [markdown]
# The code above extract the events from the trigger channel STI101. This results are represented in the array *events* where the first column is the sample and the third column the corresponding trigger value. The events_id is a dictionary of event names and trigger codes.
#
# To visualize a snippet of the events-array write:

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
# %matplotlib widget
raw.plot(start=50)
# Out:
# Using matplotlib as 2D backend.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
# %matplotlib widget
plt.stem(events[:,0][:80], events[:,2][:80])
plt.xlabel('samples')
plt.ylabel('Trigger value (STI101)')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# The figures shows an example for part of the events array. The trigger values indicate specific events of the trials.

# %% [markdown]
# ## Defining the epochs (trials) according to the event values
# Next step is to extract the left and right trials for both subparts of the data:

# %%
print(sorted(list(set(list(events_id.keys())))))
# Out:
# ['1000ms', '1500ms', '500ms', 'blank offset', 'blink', 'center', 'face01', 'face02', 'face03', 'face04', 'face05', 'face06', 'face07', 'face08', 'face09', 'face10', 'face11', 'face13', 'face14', 'face15', 'face16', 'face17', 'face18', 'face19', 'face20', 'false02', 'false03', 'false04', 'false05', 'false06', 'false07', 'false09', 'false10', 'false11', 'false12', 'false13', 'false14', 'false16', 'false17', 'false18', 'false19', 'false20', 'left', 'letter01', 'letter02', 'letter03', 'letter04', 'letter05', 'letter07', 'letter08', 'letter09', 'letter10', 'letter11', 'letter12', 'letter13', 'letter14', 'letter15', 'letter16', 'letter17', 'letter19', 'letter20', 'object01', 'object02', 'object03', 'object05', 'object06', 'object07', 'object08', 'object09', 'object10', 'object11', 'object12', 'object13', 'object14', 'object15', 'object17', 'object18', 'object19', 'response', 'right', 'sequence01', 'sequence02', 'sequence03', 'sequence04', 'sequence05', 'start experiment', 'stimulus offset', 'task irrelevant', 'task relevant non target', 'task relevant target', 'trial01', 'trial02', 'trial03', 'trial04', 'trial05', 'trial06', 'trial07', 'trial08', 'trial09', 'trial10', 'trial11', 'trial12', 'trial13', 'trial14', 'trial15', 'trial16', 'trial17', 'trial18', 'trial19', 'trial20', 'trial21', 'trial22', 'trial23', 'trial24', 'trial25', 'trial26', 'trial27', 'trial28', 'trial29', 'trial30', 'trial31', 'trial32', 'trial33', 'trial34', 'trial35', 'trial36', 'trial37', 'trial38']

# %%
raw_list = list()
events_list = list()

for subfile in range(5):
    print(subfile)
    bids_path_preproc.update(run=f"{subfile+1:02d}")

    raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)

    events, events_id = mne.events_from_annotations(raw, event_id='auto')

    raw_list.append(raw)
    events_list.append(events)

# Define event ids we are interested in
# for now we are just selecting epochs based on them being shown any face
events_picks_id = {k:v for k, v in events_id.items() if k.startswith('face') or k.startswith('object') or k.startswith('letter') or k.startswith('false')} # if k.startswith('cue')}  # took this out because I'm not sure what events we should be looking for
# Out:
# 0
# Opening raw data file drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-01_ica.fif...
#     Range : 9000 ... 511999 =      9.000 ...   511.999 secs
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: This filename (drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-01_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# Ready.
# Reading 0 ... 502999  =      0.000 ...   502.999 secs...
# Used Annotations descriptions: ['1000ms', '1500ms', '500ms', 'blank offset', 'blink', 'center', 'face01', 'face02', 'face03', 'face04', 'face05', 'face06', 'face07', 'face08', 'face09', 'face10', 'face11', 'face13', 'face14', 'face15', 'face16', 'face17', 'face18', 'face19', 'face20', 'false02', 'false03', 'false04', 'false05', 'false06', 'false07', 'false09', 'false10', 'false11', 'false12', 'false13', 'false14', 'false16', 'false17', 'false18', 'false19', 'false20', 'left', 'letter01', 'letter02', 'letter03', 'letter04', 'letter05', 'letter07', 'letter08', 'letter09', 'letter10', 'letter11', 'letter12', 'letter13', 'letter14', 'letter15', 'letter16', 'letter17', 'letter19', 'letter20', 'object01', 'object02', 'object03', 'object05', 'object06', 'object07', 'object08', 'object09', 'object10', 'object11', 'object12', 'object13', 'object14', 'object15', 'object17', 'object18', 'object19', 'response', 'right', 'sequence01', 'sequence02', 'sequence03', 'sequence04', 'sequence05', 'start experiment', 'stimulus offset', 'task irrelevant', 'task relevant non target', 'task relevant target', 'trial01', 'trial02', 'trial03', 'trial04', 'trial05', 'trial06', 'trial07', 'trial08', 'trial09', 'trial10', 'trial11', 'trial12', 'trial13', 'trial14', 'trial15', 'trial16', 'trial17', 'trial18', 'trial19', 'trial20', 'trial21', 'trial22', 'trial23', 'trial24', 'trial25', 'trial26', 'trial27', 'trial28', 'trial29', 'trial30', 'trial31', 'trial32', 'trial33', 'trial34', 'trial35', 'trial36', 'trial37', 'trial38']
# 1
# Opening raw data file drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-02_ica.fif...
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any events.tsv associated with sub-CB069_ses-1_task-dur_run-01.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*events.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any channels.tsv associated with sub-CB069_ses-1_task-dur_run-01.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*channels.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any meg.json associated with sub-CB069_ses-1_task-dur_run-01.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*meg.json"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: participants.tsv file not found for drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-01_ica.fif
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: This filename (drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-02_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
#     Range : 9000 ... 812999 =      9.000 ...   812.999 secs
# Ready.
# Reading 0 ... 803999  =      0.000 ...   803.999 secs...
# Used Annotations descriptions: ['1000ms', '1500ms', '500ms', 'blank offset', 'blink', 'center', 'face01', 'face02', 'face03', 'face04', 'face05', 'face06', 'face07', 'face08', 'face09', 'face10', 'face11', 'face12', 'face13', 'face14', 'face15', 'face16', 'face17', 'face18', 'face19', 'face20', 'false01', 'false02', 'false03', 'false04', 'false05', 'false06', 'false07', 'false08', 'false09', 'false10', 'false11', 'false12', 'false13', 'false14', 'false15', 'false16', 'false17', 'false18', 'false19', 'false20', 'left', 'letter01', 'letter02', 'letter03', 'letter04', 'letter05', 'letter06', 'letter07', 'letter08', 'letter09', 'letter10', 'letter11', 'letter12', 'letter13', 'letter14', 'letter15', 'letter16', 'letter17', 'letter18', 'letter19', 'letter20', 'object01', 'object02', 'object03', 'object04', 'object05', 'object06', 'object07', 'object08', 'object09', 'object10', 'object11', 'object12', 'object13', 'object14', 'object15', 'object16', 'object17', 'object18', 'object19', 'object20', 'response', 'right', 'sequence09', 'sequence10', 'sequence11', 'sequence12', 'sequence13', 'sequence14', 'sequence15', 'sequence16', 'stimulus offset', 'task irrelevant', 'task relevant non target', 'task relevant target', 'trial01', 'trial02', 'trial03', 'trial04', 'trial05', 'trial06', 'trial07', 'trial08', 'trial09', 'trial10', 'trial11', 'trial12', 'trial13', 'trial14', 'trial15', 'trial16', 'trial17', 'trial18', 'trial19', 'trial20', 'trial21', 'trial22', 'trial23', 'trial24', 'trial25', 'trial26', 'trial27', 'trial28', 'trial29', 'trial30', 'trial31', 'trial32', 'trial33', 'trial34', 'trial35', 'trial36', 'trial37', 'trial38']
# 2
# Opening raw data file drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-03_ica.fif...
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any events.tsv associated with sub-CB069_ses-1_task-dur_run-02.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*events.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any channels.tsv associated with sub-CB069_ses-1_task-dur_run-02.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*channels.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any meg.json associated with sub-CB069_ses-1_task-dur_run-02.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*meg.json"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: participants.tsv file not found for drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-02_ica.fif
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: This filename (drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-03_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
#     Range : 8000 ... 809999 =      8.000 ...   809.999 secs
# Ready.
# Reading 0 ... 801999  =      0.000 ...   801.999 secs...
# Used Annotations descriptions: ['1000ms', '1500ms', '500ms', 'blank offset', 'blink', 'center', 'face01', 'face02', 'face03', 'face04', 'face05', 'face06', 'face07', 'face08', 'face09', 'face10', 'face11', 'face12', 'face13', 'face14', 'face15', 'face16', 'face17', 'face18', 'face19', 'face20', 'false01', 'false02', 'false03', 'false04', 'false05', 'false06', 'false07', 'false08', 'false09', 'false10', 'false11', 'false12', 'false13', 'false14', 'false15', 'false16', 'false17', 'false18', 'false19', 'false20', 'left', 'letter01', 'letter02', 'letter03', 'letter04', 'letter06', 'letter07', 'letter08', 'letter09', 'letter10', 'letter11', 'letter12', 'letter13', 'letter14', 'letter15', 'letter16', 'letter17', 'letter18', 'letter19', 'letter20', 'object01', 'object02', 'object03', 'object04', 'object05', 'object06', 'object07', 'object08', 'object09', 'object10', 'object11', 'object12', 'object13', 'object15', 'object16', 'object17', 'object18', 'object19', 'object20', 'response', 'right', 'sequence17', 'sequence18', 'sequence19', 'sequence20', 'sequence21', 'sequence22', 'sequence23', 'sequence24', 'stimulus offset', 'task irrelevant', 'task relevant non target', 'task relevant target', 'trial01', 'trial02', 'trial03', 'trial04', 'trial05', 'trial06', 'trial07', 'trial08', 'trial09', 'trial10', 'trial11', 'trial12', 'trial13', 'trial14', 'trial15', 'trial16', 'trial17', 'trial18', 'trial19', 'trial20', 'trial21', 'trial22', 'trial23', 'trial24', 'trial25', 'trial26', 'trial27', 'trial28', 'trial29', 'trial30', 'trial31', 'trial32', 'trial33', 'trial34', 'trial35', 'trial36', 'trial37', 'trial38']
# 3
# Opening raw data file drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-04_ica.fif...
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any events.tsv associated with sub-CB069_ses-1_task-dur_run-03.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*events.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any channels.tsv associated with sub-CB069_ses-1_task-dur_run-03.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*channels.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any meg.json associated with sub-CB069_ses-1_task-dur_run-03.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*meg.json"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: participants.tsv file not found for drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-03_ica.fif
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: This filename (drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-04_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
#     Range : 8000 ... 815999 =      8.000 ...   815.999 secs
# Ready.
# Reading 0 ... 807999  =      0.000 ...   807.999 secs...
# Used Annotations descriptions: ['1000ms', '1500ms', '500ms', 'blank offset', 'blink', 'center', 'face01', 'face02', 'face03', 'face04', 'face05', 'face06', 'face07', 'face08', 'face09', 'face10', 'face11', 'face12', 'face13', 'face14', 'face15', 'face16', 'face17', 'face18', 'face19', 'face20', 'false01', 'false02', 'false03', 'false05', 'false06', 'false07', 'false08', 'false09', 'false10', 'false11', 'false12', 'false13', 'false14', 'false15', 'false16', 'false17', 'false18', 'false19', 'false20', 'left', 'letter01', 'letter02', 'letter03', 'letter04', 'letter05', 'letter06', 'letter07', 'letter08', 'letter09', 'letter10', 'letter11', 'letter12', 'letter13', 'letter14', 'letter15', 'letter16', 'letter17', 'letter18', 'letter19', 'letter20', 'object01', 'object02', 'object03', 'object04', 'object05', 'object06', 'object08', 'object09', 'object10', 'object11', 'object12', 'object13', 'object14', 'object16', 'object17', 'object18', 'object19', 'object20', 'response', 'right', 'sequence25', 'sequence26', 'sequence27', 'sequence28', 'sequence29', 'sequence30', 'sequence31', 'sequence32', 'stimulus offset', 'task irrelevant', 'task relevant non target', 'task relevant target', 'trial01', 'trial02', 'trial03', 'trial04', 'trial05', 'trial06', 'trial07', 'trial08', 'trial09', 'trial10', 'trial11', 'trial12', 'trial13', 'trial14', 'trial15', 'trial16', 'trial17', 'trial18', 'trial19', 'trial20', 'trial21', 'trial22', 'trial23', 'trial24', 'trial25', 'trial26', 'trial27', 'trial28', 'trial29', 'trial30', 'trial31', 'trial32', 'trial33', 'trial34', 'trial35', 'trial36', 'trial37', 'trial38']
# 4
# Opening raw data file drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-05_ica.fif...
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any events.tsv associated with sub-CB069_ses-1_task-dur_run-04.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*events.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any channels.tsv associated with sub-CB069_ses-1_task-dur_run-04.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*channels.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any meg.json associated with sub-CB069_ses-1_task-dur_run-04.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*meg.json"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: participants.tsv file not found for drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-04_ica.fif
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: This filename (drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-05_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
#     Range : 9000 ... 778999 =      9.000 ...   778.999 secs
# Ready.
# Reading 0 ... 769999  =      0.000 ...   769.999 secs...
# Used Annotations descriptions: ['1000ms', '1500ms', '500ms', 'blank offset', 'blink', 'center', 'face01', 'face02', 'face03', 'face04', 'face05', 'face06', 'face07', 'face08', 'face09', 'face10', 'face11', 'face12', 'face13', 'face14', 'face15', 'face16', 'face17', 'face18', 'face19', 'face20', 'false01', 'false02', 'false03', 'false04', 'false05', 'false06', 'false07', 'false08', 'false09', 'false10', 'false11', 'false12', 'false13', 'false14', 'false15', 'false16', 'false17', 'false18', 'false19', 'false20', 'left', 'letter01', 'letter02', 'letter03', 'letter04', 'letter05', 'letter06', 'letter07', 'letter08', 'letter09', 'letter10', 'letter11', 'letter12', 'letter13', 'letter14', 'letter15', 'letter16', 'letter17', 'letter18', 'letter19', 'letter20', 'object01', 'object02', 'object03', 'object04', 'object05', 'object06', 'object07', 'object08', 'object09', 'object10', 'object11', 'object12', 'object13', 'object14', 'object15', 'object16', 'object17', 'object18', 'object19', 'object20', 'offset of recording', 'response', 'right', 'sequence33', 'sequence34', 'sequence35', 'sequence36', 'sequence37', 'sequence38', 'sequence39', 'sequence40', 'stimulus offset', 'task irrelevant', 'task relevant non target', 'task relevant target', 'trial01', 'trial02', 'trial03', 'trial04', 'trial05', 'trial06', 'trial07', 'trial08', 'trial09', 'trial10', 'trial11', 'trial12', 'trial13', 'trial14', 'trial15', 'trial16', 'trial17', 'trial18', 'trial19', 'trial20', 'trial21', 'trial22', 'trial23', 'trial24', 'trial25', 'trial26', 'trial27', 'trial28', 'trial29', 'trial30', 'trial31', 'trial32', 'trial33', 'trial34', 'trial35', 'trial36', 'trial37']
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any events.tsv associated with sub-CB069_ses-1_task-dur_run-05.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*events.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any channels.tsv associated with sub-CB069_ses-1_task-dur_run-05.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*channels.tsv"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: Did not find any meg.json associated with sub-CB069_ses-1_task-dur_run-05.
#
# The search_str was "drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/**/meg/sub-CB069_ses-1*meg.json"
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)
# <ipython-input-20-2bdf665d3d70>:8: RuntimeWarning: participants.tsv file not found for drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/preprocessing/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-05_ica.fif
#   raw = read_raw_bids(bids_path=bids_path_preproc, extra_params={'preload':True}, verbose=True)

# %% [markdown]
# Now concatenate raw instances as if they were continuous - i.e combine over the 2 subfiles.

# %%
import numpy as np

# here we can see there is a very small difference in the head position between each run
# in this case we're just going to ignore that difference
print(np.array(list(raw_list[0].info['dev_head_t'].values())[2]) - np.array(list(raw_list[1].info['dev_head_t'].values())[2]))
# Out:
# [[ 3.65555286e-04  5.60667366e-03  8.22061952e-03  1.59965595e-04]
#  [-6.77175075e-03 -6.81281090e-05  3.96345556e-03 -3.26032517e-04]
#  [-7.61867035e-03 -3.45025957e-03 -6.17563725e-04 -1.70303509e-03]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]]

# %%
raw, events = mne.concatenate_raws(raw_list, events_list=events_list, on_mismatch='ignore')
del raw_list

# %%
# %matplotlib widget
raw.plot(start=50)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# Set the peak-to-peak amplitude thresholds for trial rejection. These values may change depending on the quality of the data.

# %%
reject = dict(grad=5000e-13,  # unit: T / m (gradiometers)
              mag=4e-12,      # unit: T (magnetometers)
              #eeg=40e-6,      # unit: V (EEG channels)
              #eog=250e-6      # unit: V (EOG channels)
             )

# %% [markdown]
# We will use time-windows of interest starting 2.5 s prior to the stimulus onset and ending 2 s after. Now perform the epoching using the events and events_id as well as the selected channels:

# %%
print(events_picks_id)
# Out:
# {'face01': 7, 'face02': 8, 'face03': 9, 'face04': 10, 'face05': 11, 'face06': 12, 'face07': 13, 'face08': 14, 'face09': 15, 'face10': 16, 'face11': 17, 'face12': 18, 'face13': 19, 'face14': 20, 'face15': 21, 'face16': 22, 'face17': 23, 'face18': 24, 'face19': 25, 'face20': 26, 'false01': 27, 'false02': 28, 'false03': 29, 'false04': 30, 'false05': 31, 'false06': 32, 'false07': 33, 'false08': 34, 'false09': 35, 'false10': 36, 'false11': 37, 'false12': 38, 'false13': 39, 'false14': 40, 'false15': 41, 'false16': 42, 'false17': 43, 'false18': 44, 'false19': 45, 'false20': 46, 'letter01': 48, 'letter02': 49, 'letter03': 50, 'letter04': 51, 'letter05': 52, 'letter06': 53, 'letter07': 54, 'letter08': 55, 'letter09': 56, 'letter10': 57, 'letter11': 58, 'letter12': 59, 'letter13': 60, 'letter14': 61, 'letter15': 62, 'letter16': 63, 'letter17': 64, 'letter18': 65, 'letter19': 66, 'letter20': 67, 'object01': 68, 'object02': 69, 'object03': 70, 'object04': 71, 'object05': 72, 'object06': 73, 'object07': 74, 'object08': 75, 'object09': 76, 'object10': 77, 'object11': 78, 'object12': 79, 'object13': 80, 'object14': 81, 'object15': 82, 'object16': 83, 'object17': 84, 'object18': 85, 'object19': 86, 'object20': 87}

# %%
# Make epochs (4.5 seconds centered on stim onset)
epochs = mne.Epochs(raw,
            events, events_picks_id,
            tmin=-0.2 , tmax=0.5, # time range
            baseline=None,
            proj=False,
            picks = 'meg',  # potentially other (all)
            detrend = 1,
            reject=reject,
            reject_by_annotation=True,
            preload=True,
            verbose=True)

# Show epochs details
epochs
# Out:
# Not setting metadata
# 283 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 283 events and 701 original time points ...
#     Rejecting  epoch based on MAG : ['MEG1131', 'MEG1311', 'MEG1321', 'MEG1331', 'MEG1341', 'MEG2411', 'MEG2421']
#     Rejecting  epoch based on MAG : ['MEG0211', 'MEG0231', 'MEG0241', 'MEG1331', 'MEG1341', 'MEG1421', 'MEG1431', 'MEG1611', 'MEG1621', 'MEG1641', 'MEG1721', 'MEG2231', 'MEG2311', 'MEG2321', 'MEG2341', 'MEG2411', 'MEG2421', 'MEG2431', 'MEG2441', 'MEG2521', 'MEG2611', 'MEG2641']
# 3 bad epochs dropped
# <Epochs |  280 events (all good), -0.2 – 0.5 s, baseline off, ~463.4 MB, data loaded,
#  'face01': 2
#  'face02': 5
#  'face03': 5
#  'face04': 7
#  'face05': 2
#  'face06': 4
#  'face07': 1
#  'face08': 2
#  'face09': 2
#  'face10': 5
#  and 70 more events ...>

# %% [markdown]
# By calling *epochs* we can check that the number of events is 305 of which 152 are left attention trials and 153 right attention trials. Moreover, we can see that no baseline correction was applied at this stage.
#
# Now we plot an overview of the rejected epochs:

# %%
events_id
# Out:
# {'1000ms': 1,
#  '1500ms': 2,
#  '500ms': 3,
#  'blank offset': 4,
#  'blink': 5,
#  'center': 6,
#  'face01': 7,
#  'face02': 8,
#  'face03': 9,
#  'face04': 10,
#  'face05': 11,
#  'face06': 12,
#  'face07': 13,
#  'face08': 14,
#  'face09': 15,
#  'face10': 16,
#  'face11': 17,
#  'face12': 18,
#  'face13': 19,
#  'face14': 20,
#  'face15': 21,
#  'face16': 22,
#  'face17': 23,
#  'face18': 24,
#  'face19': 25,
#  'face20': 26,
#  'false01': 27,
#  'false02': 28,
#  'false03': 29,
#  'false04': 30,
#  'false05': 31,
#  'false06': 32,
#  'false07': 33,
#  'false08': 34,
#  'false09': 35,
#  'false10': 36,
#  'false11': 37,
#  'false12': 38,
#  'false13': 39,
#  'false14': 40,
#  'false15': 41,
#  'false16': 42,
#  'false17': 43,
#  'false18': 44,
#  'false19': 45,
#  'false20': 46,
#  'left': 47,
#  'letter01': 48,
#  'letter02': 49,
#  'letter03': 50,
#  'letter04': 51,
#  'letter05': 52,
#  'letter06': 53,
#  'letter07': 54,
#  'letter08': 55,
#  'letter09': 56,
#  'letter10': 57,
#  'letter11': 58,
#  'letter12': 59,
#  'letter13': 60,
#  'letter14': 61,
#  'letter15': 62,
#  'letter16': 63,
#  'letter17': 64,
#  'letter18': 65,
#  'letter19': 66,
#  'letter20': 67,
#  'object01': 68,
#  'object02': 69,
#  'object03': 70,
#  'object04': 71,
#  'object05': 72,
#  'object06': 73,
#  'object07': 74,
#  'object08': 75,
#  'object09': 76,
#  'object10': 77,
#  'object11': 78,
#  'object12': 79,
#  'object13': 80,
#  'object14': 81,
#  'object15': 82,
#  'object16': 83,
#  'object17': 84,
#  'object18': 85,
#  'object19': 86,
#  'object20': 87,
#  'offset of recording': 88,
#  'response': 89,
#  'right': 90,
#  'sequence33': 91,
#  'sequence34': 92,
#  'sequence35': 93,
#  'sequence36': 94,
#  'sequence37': 95,
#  'sequence38': 96,
#  'sequence39': 97,
#  'sequence40': 98,
#  'stimulus offset': 99,
#  'task irrelevant': 100,
#  'task relevant non target': 101,
#  'task relevant target': 102,
#  'trial01': 103,
#  'trial02': 104,
#  'trial03': 105,
#  'trial04': 106,
#  'trial05': 107,
#  'trial06': 108,
#  'trial07': 109,
#  'trial08': 110,
#  'trial09': 111,
#  'trial10': 112,
#  'trial11': 113,
#  'trial12': 114,
#  'trial13': 115,
#  'trial14': 116,
#  'trial15': 117,
#  'trial16': 118,
#  'trial17': 119,
#  'trial18': 120,
#  'trial19': 121,
#  'trial20': 122,
#  'trial21': 123,
#  'trial22': 124,
#  'trial23': 125,
#  'trial24': 126,
#  'trial25': 127,
#  'trial26': 128,
#  'trial27': 129,
#  'trial28': 130,
#  'trial29': 131,
#  'trial30': 132,
#  'trial31': 133,
#  'trial32': 134,
#  'trial33': 135,
#  'trial34': 136,
#  'trial35': 137,
#  'trial36': 138,
#  'trial37': 139}

# %%
epochs_combined=mne.epochs.combine_event_ids(epochs, [k for k in events_id.keys() if k.startswith('face')], {"face":1001})
epochs_combined=mne.epochs.combine_event_ids(epochs_combined, [k for k in events_id.keys() if k.startswith('false')], {"false":1002})
epochs_combined=mne.epochs.combine_event_ids(epochs_combined, [k for k in events_id.keys() if k.startswith('letter')], {"latter":1003})
epochs_combined=mne.epochs.combine_event_ids(epochs_combined, [k for k in events_id.keys() if k.startswith('object')], {"object":1004})

# %%
epochs_raw=epochs
epochs=epochs_combined

# %%
# %matplotlib inline
epochs.plot_drop_log();

# %% [markdown]
# A small percentage of the trials were rejected due to MEG artefacts in the magnetometers.

# %% [markdown]
# Now we save the epoched data in an FIF-file. Note this file will include trials from the 2 subfiles.

# %%
print(deriv_fname)
# Out:
# drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/analysis/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-00_epo.fif

# %%
epochs.save(deriv_fname, overwrite=True)
# Out:
# Overwriting existing file.
# Overwriting existing file.

# %% [markdown]
# ## Plotting the trials
# To show the trials for the left-condition for the MEG gradiometers write:

# %%
epochs['face'].plot(n_epochs=10, picks=['grad'])
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# The plot above shows 10 trials of type left; only gradiometers shown.
#
# To show the trigger (stimulus channels) write:

# %%
epochs['face12'].plot(n_epochs=1, picks=['stim']) # for now this and the next block may not work properly

# %% [markdown]
# An example of the trigger channels for one trial.
#
# Showing the trigger channels is often useful for verifying that correct trials have been selected. Note that STI001 to STI016 denote the individual trigger lines which are 'on' (1) or 'off' (0). The channel STI101 is a combination of the trigger lines ( STI101 = STI001 + 2 * STI002 + 4 * STI003 + 8 * STI004 + ...)
#
# To show all the trials belonging to *left* for a representative gradiometer (MEG2343) use the plot_image function. In the following example we also lowpass filter the indvidual trials at 30 Hz and shorten them (crop) to a -100 to 400 ms interval:

# %%
# %matplotlib inline
epochs['face'].filter(0.0,30).crop(-0.1,0.4).plot_image(picks=['MEG1023'], vmin=-150, vmax=150)
# Out:
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 441 samples (0.441 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 881 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 1151 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done 1457 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done 1799 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done 2177 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done 2591 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done 3041 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done 3527 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done 4049 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done 4607 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done 5201 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 5831 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 6497 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=1)]: Done 7199 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=1)]: Done 7937 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=1)]: Done 8711 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done 9521 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done 10367 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=1)]: Done 11249 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=1)]: Done 12167 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done 13121 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=1)]: Done 14111 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=1)]: Done 15137 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=1)]: Done 16199 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=1)]: Done 17297 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=1)]: Done 18431 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=1)]: Done 19601 tasks      | elapsed:    2.8s
# Not setting metadata
# 69 matching events found
# No baseline correction applied
# 0 projection items activated
# [Parallel(n_jobs=1)]: Done 20807 tasks      | elapsed:    3.1s
# [<Figure size 640x480 with 4 Axes>]

# %% [markdown]
# ## Preregistration and publications
#
# Publication, example:
#
# "The data were segmented into intervals of 4.5 s, ranging from 2.5 s prior to stimulus onset and 2 s after. To ensure that no artefacts were missed, trials in which the gradiometers values exceeded 5000 fT/cm or magnetometers exceeded 5000 fT were rejected as well as trials previously annotated with muscle artefacts."
