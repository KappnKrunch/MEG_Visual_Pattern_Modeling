# %% [markdown]
# # Classification using a support vector machine
#
# Multi-variate pattern analysis (MVPA) is becoming increasing popular in human electrophysiological research (Cichy et al., 2014; Stokes et al, 2015;). This approach allows for identifying representational specific information associated with distributed patterns of electrophysiological activity. In this example we demonstrate how a support vector machine (SVM) can be applied to classify two classes of trials.
#
# ## Preparation
# Import the relevant modules:

# %%
# mount the drive (you'll have to click through the popup to allow it)
# google colab friendship block

from IPython.display import clear_output

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# !pip install openneuro-py
# !pip install --upgrade mne-bids[full]
# !pip install ipympl  # for the widgets in ipynb

clear_output()  # just clear everything because the output is gross and unnecessary

# %%
import os.path as op
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import mne
from mne_bids import BIDSPath
from mne.decoding import (SlidingEstimator, GeneralizingEstimator, Scaler,
                          cross_val_multiscore, LinearModel, get_coef,
                          Vectorizer, CSP)

import sklearn.svm
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# The classification is  based on the tools in the Scikit-learn (#sklearn'#) package.

# %% [markdown]
# Set the local paths of the data:

# %%
subject = 'CB069'
session = '1'
task = 'dur'  # name of the task
run = '00'  # we have two runs for this subject, let's look at run = 1
meg_suffix = 'meg'
epo_suffix = 'epo'

deriv_root = 'drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/analysis'

bids_path = BIDSPath(subject=subject, session=session, task=task, run=run, suffix=epo_suffix, datatype='meg', root=deriv_root, extension='.fif', check=False)

print(bids_path.basename, bids_path.fpath)
# Out:
# sub-CB069_ses-1_task-dur_run-00_epo.fif drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/analysis/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-00_epo.fif

# %% [markdown]
# ## Reading and preparing the trial based data
# Read the epochs:

# %%
epochs = mne.read_epochs(bids_path.fpath, preload=True, verbose=True).pick(['meg'])
# Out:
# Reading /content/drive/MyDrive/GripS MEG/Data/COGITATE/derivatives/analysis/sub-CB069/ses-1/meg/sub-CB069_ses-1_task-dur_run-00_epo.fif ...
#     Found the data of interest:
#         t =    -200.00 ...     500.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 280 matching events found
# No baseline correction applied
# 0 projection items activated

# %% [markdown]
# Now filter the data. In this case we lowpass the data at 10 Hz. This is done before cutting the trials in shorter segments in order to reduce edge effects from the filtering. The filter also serves to perform temporal smoothing of the data which will benefit the classification.

# %%
epochs_rs = epochs.copy().filter(0,10)
# Out:
# Setting up low-pass filter at 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 2.50 Hz (-6 dB cutoff frequency: 11.25 Hz)
# - Filter length: 1321 samples (1.321 s)
# <ipython-input-6-5897dd76c057>:1: RuntimeWarning: filter_length (1321) is longer than the signal (701), distortion is likely. Reduce filter length or filter a longer signal.
#   epochs_rs = epochs.copy().filter(0,10)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done 881 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done 1151 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=1)]: Done 1457 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=1)]: Done 1799 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=1)]: Done 2177 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=1)]: Done 2591 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=1)]: Done 3041 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=1)]: Done 3527 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=1)]: Done 4049 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=1)]: Done 4607 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=1)]: Done 5201 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=1)]: Done 5831 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=1)]: Done 6497 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=1)]: Done 7199 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=1)]: Done 7937 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=1)]: Done 8711 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=1)]: Done 9521 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=1)]: Done 10367 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=1)]: Done 11249 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=1)]: Done 12167 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=1)]: Done 13121 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=1)]: Done 14111 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=1)]: Done 15137 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=1)]: Done 16199 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=1)]: Done 17297 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=1)]: Done 18431 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=1)]: Done 19601 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=1)]: Done 20807 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=1)]: Done 22049 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=1)]: Done 23327 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=1)]: Done 24641 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=1)]: Done 25991 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=1)]: Done 27377 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=1)]: Done 28799 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=1)]: Done 30257 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=1)]: Done 31751 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=1)]: Done 33281 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=1)]: Done 34847 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=1)]: Done 36449 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=1)]: Done 38087 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=1)]: Done 39761 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=1)]: Done 41471 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=1)]: Done 43217 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=1)]: Done 44999 tasks      | elapsed:   37.0s
# [Parallel(n_jobs=1)]: Done 46817 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=1)]: Done 48671 tasks      | elapsed:   38.3s
# [Parallel(n_jobs=1)]: Done 50561 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=1)]: Done 52487 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=1)]: Done 54449 tasks      | elapsed:   40.4s
# [Parallel(n_jobs=1)]: Done 56447 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=1)]: Done 58481 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=1)]: Done 60551 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=1)]: Done 62657 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=1)]: Done 64799 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=1)]: Done 66977 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=1)]: Done 69191 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=1)]: Done 71441 tasks      | elapsed:   47.5s
# [Parallel(n_jobs=1)]: Done 73727 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=1)]: Done 76049 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=1)]: Done 78407 tasks      | elapsed:   50.6s
# [Parallel(n_jobs=1)]: Done 80801 tasks      | elapsed:   51.5s
# [Parallel(n_jobs=1)]: Done 83231 tasks      | elapsed:   52.4s

# %% [markdown]
# Down-sample the data to 100 Hz in order to reduce the compuatation time. Then set the time-window of interest to -0.1 to 0.5 s around the target onset.

# %%
epochs_rs.resample(100)
epochs_rs.crop(tmin=-0.1, tmax=0.5)
# Out:
# <ipython-input-7-4cc29576044d>:2: RuntimeWarning: tmax is not in time interval. tmax is set to <class 'mne.epochs.EpochsFIF'>.tmax (0.49 s)
#   epochs_rs.crop(tmin=-0.1, tmax=0.5)
# <EpochsFIF |  280 events (all good), -0.1 – 0.49 s, baseline off, ~44.4 MB, data loaded,
#  'face': 69
#  'false': 74
#  'latter': 66
#  'object': 71>

# %% [markdown]
# ## Setting up the classifier
# The SVM is implemented in the *scikit-learn* package and the corresponding application programming interface (API) must be applied.
# The matrix $X$ (features) is a three-dimensional matrix (trials  x channel x time points):

# %%
X = epochs_rs.get_data(picks='meg')
X.shape
# Out:
# (280, 306, 60)

# %% [markdown]
# In this case we have 256 trials and 61 times points.

# %% [markdown]
# The vector $y$ (also termet targets) contains 256 values indicating attention left or right trials. The trial codes (respectively 21 and 22) needs to be coverted to the values 1 and 2:

# %%
epochs.events
# Out:
# array([[ 21060,      0,   1004],
#        [ 23553,      0,   1004],
#        [ 25889,      0,   1002],
#        [ 28140,      0,   1001],
#        [ 30442,      0,   1001],
#        [ 32661,      0,   1002],
#        [ 34946,      0,   1004],
#        [ 37656,      0,   1002],
#        [ 40125,      0,   1001],
#        [ 42385,      0,   1002],
#        [ 44595,      0,   1003],
#        [ 46864,      0,   1003],
#        [ 49141,      0,   1001],
#        [ 51360,      0,   1003],
#        [ 54404,      0,   1004],
#        [ 56639,      0,   1001],
#        [ 59024,      0,   1004],
#        [ 61268,      0,   1004],
#        [ 63536,      0,   1003],
#        [ 65847,      0,   1003],
#        [ 68465,      0,   1004],
#        [ 70792,      0,   1003],
#        [ 73119,      0,   1002],
#        [ 75430,      0,   1004],
#        [ 77948,      0,   1003],
#        [ 80184,      0,   1002],
#        [ 82419,      0,   1002],
#        [ 85596,      0,   1001],
#        [ 87998,      0,   1001],
#        [ 90425,      0,   1003],
#        [ 92677,      0,   1001],
#        [ 95371,      0,   1004],
#        [ 98032,      0,   1002],
#        [100250,      0,   1004],
#        [109541,      0,   1002],
#        [111835,      0,   1001],
#        [114262,      0,   1003],
#        [116781,      0,   1003],
#        [119174,      0,   1004],
#        [121468,      0,   1003],
#        [123736,      0,   1004],
#        [126756,      0,   1001],
#        [129133,      0,   1001],
#        [131359,      0,   1004],
#        [133561,      0,   1004],
#        [135863,      0,   1001],
#        [138215,      0,   1002],
#        [140651,      0,   1002],
#        [143036,      0,   1001],
#        [145363,      0,   1002],
#        [147882,      0,   1002],
#        [150150,      0,   1004],
#        [152936,      0,   1003],
#        [155254,      0,   1002],
#        [157698,      0,   1004],
#        [160100,      0,   1001],
#        [162385,      0,   1004],
#        [164721,      0,   1004],
#        [167423,      0,   1004],
#        [169775,      0,   1001],
#        [172093,      0,   1001],
#        [174387,      0,   1003],
#        [176606,      0,   1001],
#        [179391,      0,   1003],
#        [182310,      0,   1003],
#        [184671,      0,   1001],
#        [187306,      0,   1002],
#        [189700,      0,   1002],
#        [192027,      0,   1001],
#        [194395,      0,   1004],
#        [196772,      0,   1003],
#        [203595,      0,   1002],
#        [205797,      0,   1002],
#        [208374,      0,   1003],
#        [210609,      0,   1001],
#        [212811,      0,   1002],
#        [215163,      0,   1001],
#        [217507,      0,   1004],
#        [220092,      0,   1001],
#        [222486,      0,   1003],
#        [225196,      0,   1004],
#        [227473,      0,   1001],
#        [229858,      0,   1004],
#        [232069,      0,   1002],
#        [234679,      0,   1003],
#        [236956,      0,   1004],
#        [239808,      0,   1003],
#        [242435,      0,   1002],
#        [244813,      0,   1001],
#        [247348,      0,   1002],
#        [249600,      0,   1003],
#        [251818,      0,   1003],
#        [254070,      0,   1002],
#        [256280,      0,   1001],
#        [261218,      0,   1002],
#        [263470,      0,   1003],
#        [265930,      0,   1001],
#        [268407,      0,   1004],
#        [270784,      0,   1004],
#        [273320,      0,   1004],
#        [275713,      0,   1001],
#        [277940,      0,   1003],
#        [280275,      0,   1002],
#        [282502,      0,   1004],
#        [292402,      0,   1001],
#        [294696,      0,   1002],
#        [297181,      0,   1004],
#        [299408,      0,   1002],
#        [301618,      0,   1004],
#        [304012,      0,   1001],
#        [306397,      0,   1004],
#        [308691,      0,   1003],
#        [310959,      0,   1002],
#        [313320,      0,   1004],
#        [315672,      0,   1001],
#        [318040,      0,   1002],
#        [320259,      0,   1002],
#        [322519,      0,   1003],
#        [325021,      0,   1003],
#        [327381,      0,   1001],
#        [329617,      0,   1002],
#        [331852,      0,   1003],
#        [334129,      0,   1004],
#        [336497,      0,   1004],
#        [338774,      0,   1002],
#        [341001,      0,   1003],
#        [343245,      0,   1002],
#        [345672,      0,   1003],
#        [348216,      0,   1004],
#        [350434,      0,   1002],
#        [352828,      0,   1004],
#        [355271,      0,   1003],
#        [357732,      0,   1002],
#        [360225,      0,   1002],
#        [362502,      0,   1001],
#        [364738,      0,   1001],
#        [368015,      0,   1001],
#        [370317,      0,   1001],
#        [372586,      0,   1003],
#        [403070,      0,   1004],
#        [405513,      0,   1001],
#        [407949,      0,   1004],
#        [410367,      0,   1002],
#        [412861,      0,   1001],
#        [415230,      0,   1003],
#        [417532,      0,   1003],
#        [420284,      0,   1001],
#        [422611,      0,   1003],
#        [424838,      0,   1002],
#        [427198,      0,   1003],
#        [429700,      0,   1002],
#        [432094,      0,   1001],
#        [434688,      0,   1004],
#        [436998,      0,   1001],
#        [439425,      0,   1002],
#        [441643,      0,   1002],
#        [443946,      0,   1004],
#        [446197,      0,   1004],
#        [448424,      0,   1004],
#        [450668,      0,   1003],
#        [453061,      0,   1001],
#        [455530,      0,   1002],
#        [457899,      0,   1003],
#        [460392,      0,   1004],
#        [462611,      0,   1003],
#        [464988,      0,   1001],
#        [469450,      0,   1002],
#        [471752,      0,   1002],
#        [474462,      0,   1002],
#        [476764,      0,   1004],
#        [479492,      0,   1002],
#        [481727,      0,   1002],
#        [483970,      0,   1002],
#        [486272,      0,   1002],
#        [488733,      0,   1001],
#        [498474,      0,   1002],
#        [500751,      0,   1004],
#        [503061,      0,   1002],
#        [505372,      0,   1003],
#        [507757,      0,   1004],
#        [510710,      0,   1001],
#        [513120,      0,   1001],
#        [515497,      0,   1003],
#        [517857,      0,   1001],
#        [520367,      0,   1003],
#        [522594,      0,   1002],
#        [524830,      0,   1002],
#        [527056,      0,   1002],
#        [529742,      0,   1001],
#        [531969,      0,   1003],
#        [536631,      0,   1004],
#        [540209,      0,   1004],
#        [542603,      0,   1001],
#        [544988,      0,   1003],
#        [547248,      0,   1003],
#        [549467,      0,   1003],
#        [551827,      0,   1002],
#        [554071,      0,   1002],
#        [556364,      0,   1004],
#        [558574,      0,   1003],
#        [560935,      0,   1001],
#        [563195,      0,   1004],
#        [565422,      0,   1001],
#        [567824,      0,   1002],
#        [570392,      0,   1003],
#        [572803,      0,   1003],
#        [575280,      0,   1004],
#        [577882,      0,   1003],
#        [580176,      0,   1004],
#        [582419,      0,   1001],
#        [585196,      0,   1002],
#        [595030,      0,   1003],
#        [597265,      0,   1003],
#        [599634,      0,   1001],
#        [601860,      0,   1004],
#        [604621,      0,   1003],
#        [606898,      0,   1003],
#        [609267,      0,   1003],
#        [611794,      0,   1002],
#        [614154,      0,   1001],
#        [616389,      0,   1001],
#        [618591,      0,   1002],
#        [620885,      0,   1002],
#        [623370,      0,   1004],
#        [625639,      0,   1001],
#        [627957,      0,   1004],
#        [630184,      0,   1001],
#        [632394,      0,   1003],
#        [634621,      0,   1002],
#        [636831,      0,   1002],
#        [639116,      0,   1001],
#        [641644,      0,   1004],
#        [643962,      0,   1002],
#        [646164,      0,   1001],
#        [648424,      0,   1001],
#        [651143,      0,   1002],
#        [653512,      0,   1004],
#        [655755,      0,   1002],
#        [658341,      0,   1004],
#        [660626,      0,   1003],
#        [662970,      0,   1004],
#        [665247,      0,   1003],
#        [667448,      0,   1004],
#        [669734,      0,   1001],
#        [671994,      0,   1001],
#        [674596,      0,   1004],
#        [684021,      0,   1003],
#        [686331,      0,   1004],
#        [688558,      0,   1002],
#        [690768,      0,   1002],
#        [693220,      0,   1001],
#        [695630,      0,   1001],
#        [698299,      0,   1004],
#        [700801,      0,   1002],
#        [703187,      0,   1004],
#        [705647,      0,   1001],
#        [708082,      0,   1001],
#        [710401,      0,   1002],
#        [713120,      0,   1002],
#        [715438,      0,   1004],
#        [717715,      0,   1002],
#        [720351,      0,   1001],
#        [722678,      0,   1003],
#        [725038,      0,   1004],
#        [727273,      0,   1003],
#        [729542,      0,   1001],
#        [731819,      0,   1003],
#        [734121,      0,   1003],
#        [736506,      0,   1001],
#        [739000,      0,   1003],
#        [741352,      0,   1004],
#        [743996,      0,   1004],
#        [746623,      0,   1002],
#        [748825,      0,   1002],
#        [751185,      0,   1004],
#        [754588,      0,   1004],
#        [756881,      0,   1001],
#        [759267,      0,   1003],
#        [761527,      0,   1003],
#        [763737,      0,   1004]], dtype=int32)

# %%
temp = epochs.events[:, 2]
temp[epochs.events[:, 2] == 21] = 1
temp[epochs.events[:, 2] == 22] = 2
y = temp
print(y)
# Out:
# [1004 1004 1002 1001 1001 1002 1004 1002 1001 1002 1003 1003 1001 1003
#  1004 1001 1004 1004 1003 1003 1004 1003 1002 1004 1003 1002 1002 1001
#  1001 1003 1001 1004 1002 1004 1002 1001 1003 1003 1004 1003 1004 1001
#  1001 1004 1004 1001 1002 1002 1001 1002 1002 1004 1003 1002 1004 1001
#  1004 1004 1004 1001 1001 1003 1001 1003 1003 1001 1002 1002 1001 1004
#  1003 1002 1002 1003 1001 1002 1001 1004 1001 1003 1004 1001 1004 1002
#  1003 1004 1003 1002 1001 1002 1003 1003 1002 1001 1002 1003 1001 1004
#  1004 1004 1001 1003 1002 1004 1001 1002 1004 1002 1004 1001 1004 1003
#  1002 1004 1001 1002 1002 1003 1003 1001 1002 1003 1004 1004 1002 1003
#  1002 1003 1004 1002 1004 1003 1002 1002 1001 1001 1001 1001 1003 1004
#  1001 1004 1002 1001 1003 1003 1001 1003 1002 1003 1002 1001 1004 1001
#  1002 1002 1004 1004 1004 1003 1001 1002 1003 1004 1003 1001 1002 1002
#  1002 1004 1002 1002 1002 1002 1001 1002 1004 1002 1003 1004 1001 1001
#  1003 1001 1003 1002 1002 1002 1001 1003 1004 1004 1001 1003 1003 1003
#  1002 1002 1004 1003 1001 1004 1001 1002 1003 1003 1004 1003 1004 1001
#  1002 1003 1003 1001 1004 1003 1003 1003 1002 1001 1001 1002 1002 1004
#  1001 1004 1001 1003 1002 1002 1001 1004 1002 1001 1001 1002 1004 1002
#  1004 1003 1004 1003 1004 1001 1001 1004 1003 1004 1002 1002 1001 1001
#  1004 1002 1004 1001 1001 1002 1002 1004 1002 1001 1003 1004 1003 1001
#  1003 1003 1001 1003 1004 1004 1002 1002 1004 1004 1001 1003 1003 1004]

# %% [markdown]
# The function *make_pipeline* is from *scikit-learn*. It defines the transforms used with the estimator. The *Vectorizer()* transforms X into a 2D array (samples by features).
# The *StandardScaler()* standardize the data by removing the mean and scaling to unit variance.

# %%
clf = make_pipeline(Vectorizer(),StandardScaler(), LinearModel(sklearn.svm.SVC(kernel = 'linear')))

# %% [markdown]
# Finally the estimator must be defined. We here apply the *SlidingEstimator* that uses the features $X$ and targets $y$ as input as well as *clf* defining the pipeline. The aim is to discriminate the experimental conditions as functions of time; i.e. at which time points can we tell left from right attention?

# %%
time_decod = SlidingEstimator(clf, n_jobs=-1, verbose=True)#, scoring='roc_auc')

# %% [markdown]
# ## Performing the classification ##
# The classification will be performed timepoint by timepoint using a SVM by training on 80% of the trials on test on 20% in 5 runs. This  results in a 5-fold cross-validation (*cv=5*). The output will be reported as Area Under the Curve (AUC).

# %%
scores = cross_val_multiscore(time_decod, X, y, cv=5, n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   59.2s finished

# %% [markdown]
# ## Plotting the results
# In order to plot the results, average over scores and plot:

# %%
scores = np.mean(scores, axis=0)

# %%
fig, ax = plt.subplots()
#plt.ylim([0.35, 0.65])
ax.plot(epochs_rs.times, scores, label='score')
ax.axhline(.25, color='k', linestyle='--', label='chance')
ax.set_xlabel('Times')
ax.set_ylabel('other metric')  # Area Under the Curve not AUC
ax.legend()
ax.axvline(.0, color='k', linestyle='-')
ax.set_title('Sensor space decoding')
# Out:
# Text(0.5, 1.0, 'Sensor space decoding')

# %% [markdown]
# The plots show the accuracy (AUC) of the classification as a function of time. The best classiciation is obtained ~200 ms after the target onset and is about 0.64.

# %% [markdown]
# ## Preregistration and publications
#
# Publication, example:
#
# "A multi-variate pattern analysis was applied to the MEG data to classify whether the participants attended left or right. The data were lowpass filtered at 10 Hz and then downsampled to 100 Hz. The time-points in the interval -0.1 to 0.5 s around the target onset was considered. The data were standardized by removing the mean and scaling to unit variance per sensor. A support vector machine (Cortes abd Vapnik, 1995) from Scikit-learn (https://scikit-learn.org/) was applied to classify the data as a function of time. A 5-fold cross-validation procedure was used and the classificaiton rate was reported as Area Under the Curve"

# %% [markdown]
# ## References
#
# * Cichy RM, Pantazis D, Oliva A.(2014) Resolving human object recognition in space and time. Nat Neurosci. 17(3):455-62. doi: 10.1038/nn.3635
# * Cortes, C, Vapnik, V (1995) Support-vector networks. Mach Learn 20, 273–297
# * Stokes MG, Wolff MJ, Spaak E. (2015) Decoding Rich Spatial Information with High Temporal Resolution. Trends Cogn Sci. 19(11):636-638. doi: 10.1016/j.tics.2015.08.016
